# %%
import json
import os
import random
import re
import tempfile
import pandas as pd

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>")) # jupyter notebook full-width display
display(HTML("<style>.dataframe td { white-space: nowrap; }</style>")) # no text wrapping

# pandas formatting
pd.set_option('display.float_format', '{:.1f}'.format)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 200)
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.dataframe td { white-space: nowrap; }</style>

# %% [markdown]
# # import url data

# %%
links_folder = "website_reports"

dataframes = []

for file in os.listdir(links_folder):
    if file.endswith(".xlsx"):
        file_path = os.path.join(links_folder, file)
        df = pd.read_excel(file_path)
        dataframes.append(df)

column_names = ['type', 'year', 'pub_number', '_', 'nom', 'name', 'url_fr', 'url_en', '_', '_', '_', '_']
combined_df = pd.concat(dataframes, ignore_index=True)
combined_df.columns = column_names

types = ['RES', 'SAR', 'PRO', 'SSR', 'SCR', 'ESR', 'HSR']
combined_df = combined_df[combined_df.type.isin(types)]
combined_df = combined_df.loc[:, combined_df.columns != '_']

combined_df.sample(10)
# Out:
#       type  year pub_number  \
# 12984  RES  2014   2014/013
# 4973   RES  1995   1995/114
# 18993  SCR  2018   2018/053
# 694    PRO  2010   2010/017
# 19046  SCR  2020   2020/008
# 11045  RES  2010   2010/091
# 9826   RES  2007   2007/005
# 1095   PRO  2016   2016/010
# 1684   RES  1980   1980/001
# 18604  SCR  2008   2008/006
#
#                                                                                                                                                                                                            nom  \
# 12984  Comparaison de l'âge, de la croissance et de la mortalité d'ombles de fontaine (Salvelinus fontinalis) échantillonnées dans sept lacs de la péninsule Northern sur l'île de Terre-euve afin d'évalue...
# 4973                                                                                                                                                                                                       NaN
# 18993                                                                              Évaluation de l'approche des conditions de référence pour la surveillance des activités d'exploitation des placers du Yukon
# 694                       Processus consultatif régional sur les possibilités de pêches de la capucette et du balaou dans la partie néo-écossaise du sud du golfe du Saint-Laurent; les 15 et 16 décembre 2009
# 19046        Mise à jour des indices d'abondance jusqu'en 2019 pour les stocks de Plie Rouge de la Div. 4T de l'OPANO, de Plie Grise des Divs. 4RST de l'OPANO et de Merluche Blanche de la Div. 4T de l'OPANO
# 11045                                                                 Évaluation de stock de crabe des neiges, (Chionoecetes opilio), dans le sud du golfe du Saint-Laurent (zones 12, 19, 12E et 12F) en 2009
# 9826                                                                                                   Zones de production de pétoncle de la baie de Fundy : état des stocks pour 2006 et prévisions pour 2007
# 1095         Compte rendu de l'examen zonal par les pairs préalable à l'évaluation du COSEPAC concernant l'esturgeon jaune (Acipenser fulvescens), unités désignables 7-8, au Canada; les 3 et 4 novembre 2015
# 1684                                                                                                                                                                                                       NaN
# 18604             Programme de levés géophysiques dans l'ouest de T. N. L. de NWest Energy Inc. Examen de la section sur les relevés relatifs aux pêches commerciales du rapport d'évaluation environnementale
#
#                                                                                                                                                                                                           name  \
# 12984  Comparing Age, Growth, and Mortality of Brook Trout (Salvelinus fontinalis) sampled from Seven Lakes on the Northern Peninsula, Newfoundland to assess the efficacy of established regulations for T...
# 4973                                                                                                                 Correspondence analysis of length frequencies of cod samples from 4T, 4Vn, and 4Vs (9 p.)
# 18993                                                                                                                        Evaluation of the reference condition approach for Yukon placer mining monitoring
# 694                        Regional Advisory Process on Opportunity for Atlantic silverside and Atlantic saury fisheries in the Nova Scotia portion of the southern Gulf of St. Lawrence; December 15-16, 2009
# 19046                                                         Updated indices of abundance to 2019 for Winter Flounder from NAFO Div. 4T, Witch Flounder from NAFO Divs. 4RST and White Hake from NAFO Div. 4T
# 11045                                                                          The 2009 assessment of snow crab, (Chionoecetes opilio), stock in the southern Gulf of St. Lawrence (Areas 12, 19, 12E and 12F)
# 9826                                                                                                                 Scallop Production Areas in the Bay of Fundy: Stock Status for 2006 and Forecast for 2007
# 1095                                         Proceedings of the zonal peer review of the Pre-COSEWIC Assessment for Lake Sturgeon, Acipenser fulvescens, Designatable Units 7-8, in Canada; November 3-4, 2015
# 1684                                                                                                                                                                            Assessment of 4VWX-5-6 pollock
# 18604                                                                                                                         NWest Energy Inc. Western NL Geophysical survey program: review of The EA report
#
#                                                                                        url_fr  \
# 12984  http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/2014/2014_013-fra.html
# 4973   http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1995/1995_114-fra.html
# 18993           http://www.dfo-mpo.gc.ca/csas-sccs/Publications/ScR-RS/2018/2018_053-fra.html
# 694              http://www.dfo-mpo.gc.ca/csas-sccs/publications/pro-cr/2010/2010_017-fra.htm
# 19046           http://www.dfo-mpo.gc.ca/csas-sccs/Publications/ScR-RS/2020/2020_008-fra.html
# 11045  http://www.dfo-mpo.gc.ca/csas-sccs/Publications/ResDocs-DocRech/2010/2010_091-fra.html
# 9826    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/2007/2007_005-fra.htm
# 1095            http://www.dfo-mpo.gc.ca/csas-sccs/Publications/Pro-Cr/2016/2016_010-fra.html
# 1684   http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1980/1980_001-fra.html
# 18604            http://www.dfo-mpo.gc.ca/csas-sccs/publications/scr-rs/2008/2008_006-fra.htm
#
#                                                                                        url_en
# 12984  http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/2014/2014_013-eng.html
# 4973   http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1995/1995_114-eng.html
# 18993           http://www.dfo-mpo.gc.ca/csas-sccs/Publications/ScR-RS/2018/2018_053-eng.html
# 694              http://www.dfo-mpo.gc.ca/csas-sccs/publications/pro-cr/2010/2010_017-eng.htm
# 19046           http://www.dfo-mpo.gc.ca/csas-sccs/Publications/ScR-RS/2020/2020_008-eng.html
# 11045  http://www.dfo-mpo.gc.ca/csas-sccs/Publications/ResDocs-DocRech/2010/2010_091-eng.html
# 9826    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/2007/2007_005-eng.htm
# 1095            http://www.dfo-mpo.gc.ca/csas-sccs/Publications/Pro-Cr/2016/2016_010-eng.html
# 1684   http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1980/1980_001-eng.html
# 18604            http://www.dfo-mpo.gc.ca/csas-sccs/publications/scr-rs/2008/2008_006-eng.htm

# %%
# most docs with url_fr == url_en seem to be documents with translations in the same doc 
# DO NOT REMOVE THESE

combined_df[combined_df.url_fr == combined_df.url_en].sample(10)
# Out:
#       type  year  pub_number  \
# 19688  SSR  1999  1999/A2-02
# 359    PRO  2003    2003/017
# 32     PRO  1996    1996/001
# 506    PRO  2006    2006/046
# 213    PRO  2001    2001/041
# 422    PRO  2004    2004/049
# 456    PRO  2005    2005/029
# 554    PRO  2007    2007/033
# 197    PRO  2000    2000/014
# 19858  SSR  2001  2001/C2-07
#
#                                                                                                                                                                                 nom  \
# 19688                                                                                                                                                                           NaN
# 359                                                                                          Procès-verbal de la réunion du souscomité du poisson de fond du CEESP; le 20 mai 2003.
# 32                                                                                                                                                                              NaN
# 506                                        Compte rendu de la réunion du Processus consultatif régional concernant la crevette de l'est du plateau néo-écossais; le 5 décembre 2006
# 213    Procès-verbale des séances d'examen par les pairs pour le crabe des neiges du Sud du golfe du Saint-Laurent Région de geation des pêches du Golfe; du 13 au 16 février 2001.
# 422                   Réunion du Processus consultatif régional des provinces Maritimes Mise à jour des évaluations des stocks de pétoncle des APP 1,3,4,5 et 6; 8-9 décembre 2004.
# 456                                                                     Compte rendu des réunions du Processus consultatif régional sur les pétoncles de la ZPP 29; le 12 mai 2005.
# 554                                                                                                        Évaluations des pêches dans la rivière Saguenay en 2006; 24 octobre 2006
# 197                                                                                                                                                                             NaN
# 19858                                                                                                                                                                           NaN
#
#                                                                                                                                                name  \
# 19688                                                                                                                           Subdivision 3Ps cod
# 359                                                                         Proceedings of the PSARC Groundfish Subcommittee Meeting; May 20, 2003.
# 32                                 Proceedings of Peer Review and Client Consultations for Diadromous Fish Stocks in the Maritime Provinces in 1995
# 506                                         Proceedings of the Maritimes Regional Advisory Process on Eastern Scotian Shelf Shrimp; 5 December 2006
# 213          Proceedings of the Peer Review of Snow Crab Stocks in the Gulf of St. Lawrence Gulf Fisheries Management Region; February 13-16, 2001.
# 422          Proceedings of the Maritimes Regional Advisory Process Stock Assessment Update of SPA 1,3,4,5 and 6 Scallop Stocks; 8-9 December 2004.
# 456                                             Proceedings of the Maritime Provinces Regional Advisory Process on Scallops in SFA 29; 12 May 2005.
# 554                                                                           Assessments of fishery in the Saguenay River in 2006; October 24 2006
# 197    Proceedings of a Workshop on the Ecosystem Considerations for the Eastern Scotian Shelf Integrated Management (ESSIM) Area; 19-23 June 2000.
# 19858                                                                                                  Iceland Scallop in Newfoundland and Labrador
#
#                                                        url_fr  \
# 19688    http://waves-vagues.dfo-mpo.gc.ca/Library/234379.pdf
# 359      http://waves-vagues.dfo-mpo.gc.ca/Library/274209.pdf
# 32       http://waves-vagues.dfo-mpo.gc.ca/Library/197005.pdf
# 506    http://waves-vagues.dfo-mpo.gc.ca/Library/40511571.pdf
# 213      http://waves-vagues.dfo-mpo.gc.ca/Library/264840.pdf
# 422      http://waves-vagues.dfo-mpo.gc.ca/Library/319426.pdf
# 456      http://waves-vagues.dfo-mpo.gc.ca/Library/322811.pdf
# 554      http://waves-vagues.dfo-mpo.gc.ca/Library/330790.pdf
# 197      http://waves-vagues.dfo-mpo.gc.ca/Library/251122.pdf
# 19858    http://waves-vagues.dfo-mpo.gc.ca/Library/254392.pdf
#
#                                                        url_en
# 19688    http://waves-vagues.dfo-mpo.gc.ca/Library/234379.pdf
# 359      http://waves-vagues.dfo-mpo.gc.ca/Library/274209.pdf
# 32       http://waves-vagues.dfo-mpo.gc.ca/Library/197005.pdf
# 506    http://waves-vagues.dfo-mpo.gc.ca/Library/40511571.pdf
# 213      http://waves-vagues.dfo-mpo.gc.ca/Library/264840.pdf
# 422      http://waves-vagues.dfo-mpo.gc.ca/Library/319426.pdf
# 456      http://waves-vagues.dfo-mpo.gc.ca/Library/322811.pdf
# 554      http://waves-vagues.dfo-mpo.gc.ca/Library/330790.pdf
# 197      http://waves-vagues.dfo-mpo.gc.ca/Library/251122.pdf
# 19858    http://waves-vagues.dfo-mpo.gc.ca/Library/254392.pdf

# %%
# how many pdf links are missing?

combined_df[combined_df['url_en'].str.endswith(('html', 'htm'))]['type'].value_counts()
# Out:
# type
# RES    5064
# SAR    1128
# PRO     843
# SCR     656
# ESR       1
# Name: count, dtype: int64

# %%
# create formatted pub number with type and number
combined_df['formatted_pub_number'] = combined_df['type'] + " " + combined_df['pub_number']

combined_df.sample(1).T
# Out:
#                                                                                                         4016
# type                                                                                                     RES
# year                                                                                                    1992
# pub_number                                                                                          1992/061
# nom                                                                                                      NaN
# name                               Why was inshore capelin (Mallotus villosus) spawning delayed during 1991?
# url_fr                http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1992/1992_061-fra.html
# url_en                http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1992/1992_061-eng.html
# formatted_pub_number                                                                            RES 1992/061

# %%
# how many are html links vs pdf links?
display(combined_df['url_en'].str.endswith(('html', 'htm')).value_counts())
display(combined_df['url_en'].str.endswith('pdf').value_counts())
# Out:
# url_en
# True     7692
# False    1369
# Name: count, dtype: int64
# url_en
# False    7692
# True     1369
# Name: count, dtype: int64

# %% [markdown]
# # import ParsedPublication data

# %%
parsed_docs_folder = os.path.join("..", "ParsedPublications")

type_dict = {
    'RES': ['research document', 'res. doc. no.', 'res. doc.', 'res doc', 'res.doc.', 'res no.', 'resdoc', 'res.', 'res', 'documents de recherche', 'document de recherche'],
    'SCR': ['science response', 'science response report', 'réponse des sciences', 'réponses des sciences', 'réponse scientifique'],
    'PRO': ['proceedings series', 'compte rendu', 'compte rendus', 'comptes rendu', 'comptes rendus'],
    'SAR': ['science advisory report', 'avis scientifique'],
}
data = []
errors = dict()

def extract_pub_number(text, filename):
    text_snippet = re.sub(r"\s+", " ", text[:2000].lower())
    
    for key, phrases in type_dict.items():
        pattern = re.compile(r"(" + "|".join(re.escape(phrase.lower()) for phrase in phrases) + r")", flags=re.IGNORECASE)
        text_snippet = pattern.sub(key, text_snippet)

    # # original chatgpt regex with issue (leaves in spaces, but that prevents normaize and zero padding below)
    # patterns = [rf"{key}\.?(?:\s+no\.)?\s+\d{{2,4}}\s*/\s*\d{{1,3}}" for key in type_dict.keys()]  # 1806
    
    # # copilot regex prompted to fix the issue (got worse, asked for help, same exact code)
    # text_snippet = re.sub(r"(\d)\s+(\d)", r"\1\2", text_snippet)
    # patterns = [rf"{key}\.?(?:\s+no\.)?\s+\d{{2,4}}/\d{{1,3}}" for key in type_dict.keys()]
    
    # deepseek-coder-v2:latest
    # patterns = [rf"{key}\.?(?:\s+no\.)?\s+\d{{2,4}}\s*/\s*(?:\s*\d{1,3})" for key in type_dict.keys()]  # 12680 missing pub numbers
    patterns = [rf"{key}.?(?:\s+no.)?\s+\d{{2,4}}\s*/\s*\d(?:\s*\d){{0,2}}" for key in type_dict.keys()] # 1791 copilot version of the same question
    
    for pattern in patterns:
        match = re.search(pattern, text_snippet, re.IGNORECASE)
        if match:
            pub_number = match.group()
            pub_number = f"{pub_number.split()[0]} {"".join(pub_number.split()[1:])}"  # kevin solution 
            
            # Normalize 2-digit years to 4 digits (e.g., 77 -> 1977)
            pub_number = re.sub(r" (\d{2})/", lambda m: f" 19{m.group(1)}/" if int(m.group(1)) <= 99 else f" {m.group(1)}/", pub_number)
            
            # Zero-pad publication numbers (e.g., 15 -> 015)
            pub_number = re.sub(r"/(\d{1,2})(?!\d)", lambda m: f"/{int(m.group(1)):03}", pub_number)
            return pub_number
    
    errors[filename] = " ".join(text_snippet.split())
    return None

for year_folder in os.listdir(parsed_docs_folder):
    min_year = 1977
    max_year = 2024
    
    if year_folder.isnumeric():
        if min_year <= int(year_folder) <= max_year:
            year_path = os.path.join(parsed_docs_folder, year_folder)
            print(f"Analysing: {year_path}")
            
            if os.path.isdir(year_path):
                for json_file in os.listdir(year_path):
                    if json_file.endswith(".json"):
                        json_path = os.path.join(year_path, json_file)
                        with open(json_path, 'r', encoding='utf-8') as file:
                            json_data = json.load(file)
                            
                            filename = json_data.get('name')
                            url = json_data.get('url')
                            year = json_data.get('publicationYear')
                            text = json_data.get('text', '')
                            pub_number = extract_pub_number(text, filename)
                            
                            data.append({
                                'filename': filename,
                                'url': url,
                                'year': year,
                                'pub_number': pub_number
                            })

parsed_docs_df = pd.DataFrame(data)

print('\nnumber of missing pub numbers:', len(errors))  # was 1806 (chatgpt with bug), 1990 (copilot fixing the bug)
# Out:
# Analysing: ..\ParsedPublications\1977
# Analysing: ..\ParsedPublications\1978
# Analysing: ..\ParsedPublications\1979
# Analysing: ..\ParsedPublications\1980
# Analysing: ..\ParsedPublications\1981
# Analysing: ..\ParsedPublications\1982
# Analysing: ..\ParsedPublications\1983
# Analysing: ..\ParsedPublications\1984
# Analysing: ..\ParsedPublications\1985
# Analysing: ..\ParsedPublications\1986
# Analysing: ..\ParsedPublications\1987
# Analysing: ..\ParsedPublications\1988
# Analysing: ..\ParsedPublications\1989
# Analysing: ..\ParsedPublications\1990
# Analysing: ..\ParsedPublications\1991
# Analysing: ..\ParsedPublications\1992
# Analysing: ..\ParsedPublications\1993
# Analysing: ..\ParsedPublications\1994
# Analysing: ..\ParsedPublications\1995
# Analysing: ..\ParsedPublications\1996
# Analysing: ..\ParsedPublications\1997
# Analysing: ..\ParsedPublications\1998
# Analysing: ..\ParsedPublications\1999
# Analysing: ..\ParsedPublications\2000
# Analysing: ..\ParsedPublications\2001
# Analysing: ..\ParsedPublications\2002
# Analysing: ..\ParsedPublications\2003
# Analysing: ..\ParsedPublications\2004
# Analysing: ..\ParsedPublications\2005
# Analysing: ..\ParsedPublications\2006
# Analysing: ..\ParsedPublications\2007
# Analysing: ..\ParsedPublications\2008
# Analysing: ..\ParsedPublications\2009
# Analysing: ..\ParsedPublications\2010
# Analysing: ..\ParsedPublications\2011
# Analysing: ..\ParsedPublications\2012
# Analysing: ..\ParsedPublications\2013
# Analysing: ..\ParsedPublications\2014
# Analysing: ..\ParsedPublications\2015
# Analysing: ..\ParsedPublications\2016
# Analysing: ..\ParsedPublications\2017
# Analysing: ..\ParsedPublications\2018
# Analysing: ..\ParsedPublications\2019
# Analysing: ..\ParsedPublications\2020
# Analysing: ..\ParsedPublications\2021
# Analysing: ..\ParsedPublications\2022
# Analysing: ..\ParsedPublications\2023
# Analysing: ..\ParsedPublications\2024
#
# number of missing pub numbers: 1791

# %%
parsed_docs_df.sample(10)
# Out:
#            filename  \
# 9415   40610573.pdf
# 12475  41240509.pdf
# 3558     256631.pdf
# 698       91385.pdf
# 4494     281862.pdf
# 5669     343519.pdf
# 12340  4120671x.pdf
# 1028     115912.pdf
# 1089     116594.pdf
# 6321     340252.pdf
#
#                                                                         url  \
# 9415   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/40610573.pdf
# 12475  https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/41240509.pdf
# 3558                   http://waves-vagues.dfo-mpo.gc.ca/Library/256631.pdf
# 698       https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/91385.pdf
# 4494     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/281862.pdf
# 5669                   http://waves-vagues.dfo-mpo.gc.ca/Library/343519.pdf
# 12340  https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/4120671x.pdf
# 1028     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/115912.pdf
# 1089     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/116594.pdf
# 6321     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/340252.pdf
#
#        year    pub_number
# 9415   2016  SCR 2016/031
# 12475  2023  SCR 2024/009
# 3558   2001  PRO 2001/018
# 698    1986  RES 1986/043
# 4494   2004  RES 2004/003
# 5669   2007  PRO 2007/059
# 12340  2023  SAR 2023/037
# 1028   1990  RES 1990/007
# 1089   1990  RES 1990/069
# 6321   2009  RES 2009/110

# %%
# check some random errors (mostly look like stock status reports)

random_error = random.choice(list(errors.keys()))

print(random_error)
print(errors[random_error])
# Out:
# 211673.pdf
# fisheries pêches and oceans et océans dfo science maritimes region stock status report d3-10 april 1997 atlantic salmon eastern shore nova scotia sfa 20 the fishery the 1996 angling fishery was limited to a hook-and-release fishery except on east river, sheet harbour, where a small salmon harvest was permitted. the angling seasons were extended at the request of client groups on east river sheet harbour by one month until september 30; on the liscomb river by 17 days until september 15; and on the st. mary’s river, by 46 days from an earlier opening date of may 10 to a later closing date of september 30. the seasons on the remaining rivers in the area have not changed for several years and were open from june 1 to august 29 except those in the eastern portion of the area which were open from june 24 to september 22. the atlantic salmon sport catch on these rivers, as estimated from license stubs, was 21 small salmon retained (east river), 862 small salmon released and 335 large salmon released. the preliminary total small salmon ` background sfa 20 is located on the eastern shore of nova scotia between the city of dartmouth and the strait of canso. many of the rivers in the area are acid-stRESsed with some loss of salmon production potential. about 20 rivers in sfa 20 are fished regularly and three rivers (musquodoboit; salmon, guysborough; and st. mary’s), which are not seriously affected by acidity, yield the largest proportion of the fish angled in the area. stock status was determined for five stocks within sfa 20 in 1996. assessments compared conservation requirements against spawning escapements determined either from a mark-and-recapture experiment (musquodoboit river) or through the use of capture rates in the angling fishery. in the st. mary’s river stock, approximately one-half of the spawning requirement is expected to come from small salmon (<63 cm), which are 50% female. the musquodoboit river salmon stock is comprised of 40

# %%
display_in_notepad = False

def display_errors_in_notepad(errors):
    n_char = 400
    
    with tempfile.NamedTemporaryFile(delete=False, mode='w', suffix='.txt', encoding='utf-8') as temp_file:
        for k, v in errors.items():
            v = v[:n_char].lower()
            
            if "stock status report" not in v:
                temp_file.write(f'++++++++++++++++++++ {k} ++++++++++++++++++++\n')
                temp_file.write(f'{v}\n\n')
        temp_file_name = temp_file.name
    
    os.system(f'notepad {temp_file_name}')
    os.unlink(temp_file_name)

if display_in_notepad:
    display_errors_in_notepad(errors)

# %%
parsed_docs_df['pub_number'].isna().value_counts()  # why doesn't this match len(errors)
# Out:
# pub_number
# False    10930
# True      1822
# Name: count, dtype: int64

# %% [markdown]
# # how many parsedpublications matches are missing for documents with translations?

# %%
missing_pub_numbers = [x for x in combined_df.formatted_pub_number.to_list() if x not in parsed_docs_df.pub_number.to_list()]

len(missing_pub_numbers)
# Out:
# 1076

# %%
combined_df[combined_df.formatted_pub_number.isin(missing_pub_numbers) & combined_df['url_en'].str.endswith(('html', 'htm'))].drop(['pub_number', 'name', 'nom'], axis=1).sample(20)
# Out:
#       type  year  \
# 469    PRO  2005
# 2110   RES  1983
# 1899   RES  1981
# 6405   RES  1999
# 6431   RES  1999
# 4329   RES  1993
# 17051  RES  2024
# 5066   RES  1996
# 1730   RES  1980
# 7169   RES  2000
# 7411   RES  2001
# 3322   RES  1989
# 8293   RES  2002
# 8719   RES  2003
# 731    PRO  2010
# 1635   RES  1979
# 6850   RES  1999
# 1979   RES  1982
# 1647   RES  1979
# 6798   RES  1999
#
#                                                                                         url_fr  \
# 469                   http://www.dfo-mpo.gc.ca/csas-sccs/publications/withdrawn-retire-fra.htm
# 2110    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1983/1983_017-fra.html
# 1899    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1981/1981_041-fra.html
# 6405     http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1999/1999_045-fra.htm
# 6431     http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1999/1999_055-fra.htm
# 4329    http://www.dfo-mpo.gc.ca/csas-sccs/Publications/ResDocs-DocRech/1993/1993_067-fra.html
# 17051  https://www.dfo-mpo.gc.ca/csas-sccs/Publications/ResDocs-DocRech/2024/2024_070-fra.html
# 5066     http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1996/1996_004-fra.htm
# 1730    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1980/1980_031-fra.html
# 7169     http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/2000/2000_109-fra.htm
# 7411     http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/2001/2001_022-fra.htm
# 3322    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1989/1989_016-fra.html
# 8293                  http://www.dfo-mpo.gc.ca/csas-sccs/publications/withdrawn-retire-fra.htm
# 8719                  http://www.dfo-mpo.gc.ca/csas-sccs/publications/withdrawn-retire-fra.htm
# 731              http://www.dfo-mpo.gc.ca/csas-sccs/Publications/Pro-Cr/2010/2010_034-fra.html
# 1635    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1979/1979_021-fra.html
# 6850                  http://www.dfo-mpo.gc.ca/csas-sccs/publications/withdrawn-retire-fra.htm
# 1979    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1982/1982_005-fra.html
# 1647    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1979/1979_030-fra.html
# 6798     http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1999/1999_185-fra.htm
#
#                                                                                         url_en  \
# 469                   http://www.dfo-mpo.gc.ca/csas-sccs/publications/withdrawn-retire-eng.htm
# 2110    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1983/1983_017-eng.html
# 1899    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1981/1981_041-eng.html
# 6405     http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1999/1999_045-eng.htm
# 6431     http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1999/1999_055-eng.htm
# 4329    http://www.dfo-mpo.gc.ca/csas-sccs/Publications/ResDocs-DocRech/1993/1993_067-eng.html
# 17051  https://www.dfo-mpo.gc.ca/csas-sccs/Publications/ResDocs-DocRech/2024/2024_070-eng.html
# 5066     http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1996/1996_004-eng.htm
# 1730    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1980/1980_031-eng.html
# 7169     http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/2000/2000_109-eng.htm
# 7411     http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/2001/2001_022-eng.htm
# 3322    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1989/1989_016-eng.html
# 8293                  http://www.dfo-mpo.gc.ca/csas-sccs/publications/withdrawn-retire-eng.htm
# 8719                  http://www.dfo-mpo.gc.ca/csas-sccs/publications/withdrawn-retire-eng.htm
# 731              http://www.dfo-mpo.gc.ca/csas-sccs/Publications/Pro-Cr/2010/2010_034-eng.html
# 1635    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1979/1979_021-eng.html
# 6850                  http://www.dfo-mpo.gc.ca/csas-sccs/publications/withdrawn-retire-eng.htm
# 1979    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1982/1982_005-eng.html
# 1647    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1979/1979_030-eng.html
# 6798     http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1999/1999_185-eng.htm
#
#       formatted_pub_number
# 469           PRO 2005/021
# 2110          RES 1983/017
# 1899          RES 1981/041
# 6405          RES 1999/045
# 6431          RES 1999/055
# 4329          RES 1993/067
# 17051         RES 2024/070
# 5066          RES 1996/004
# 1730          RES 1980/031
# 7169          RES 2000/109
# 7411          RES 2001/022
# 3322          RES 1989/016
# 8293          RES 2002/037
# 8719          RES 2003/113
# 731           PRO 2010/034
# 1635          RES 1979/021
# 6850          RES 1999/003
# 1979          RES 1982/005
# 1647          RES 1979/030
# 6798          RES 1999/185

# %%
combined_df[combined_df.formatted_pub_number == "RES 1999/017"].T
# Out:
#                                                                                                                          6312
# type                                                                                                                      RES
# year                                                                                                                     1999
# pub_number                                                                                                           1999/017
# nom                                                                                                                       NaN
# name                  Flatfish Stock Assessment for the West Coast of Canada for 1998 and recommended yield options for 1999.
# url_fr                                  http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1999/1999_017-fra.htm
# url_en                                  http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1999/1999_017-eng.htm
# formatted_pub_number                                                                                             RES 1999/017

# %%
parsed_docs_df[parsed_docs_df.pub_number == "RES 1999/017"].T  

# TODO (NOTE) IT WORKS!!! -> "Research Document 99/ 1 7" is correctly converted to"RES 1999/017"
# Out:
#                                                                           2756
# filename                                                            233840.pdf
# url         https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/233840.pdf
# year                                                                      1999
# pub_number                                                        RES 1999/017

# %%
# manually check:

# errors['314807.pdf']  # this one is literally the only ESR with out PDF data, I didn't include it in the original script, but I could add manually: (id, fr, en) = (ESR 2004/006, 314807.pdf, 314806.pdf)
# a bunch have been withdrawn 
# errors['102275.pdf'] # not an error: translation is right inside the same document, single pdf (also 186156.pdf, 79442.pdf, and more)

errors.get('277.pdf')  # TODO: this doesn't match because the generated pub_number formatting was incorrect "Res. Doc. 81/ 51" was converted to "RES 1981/ 51", should be "RES 1981/051"

# %%
# TODO: somehow a pub_number of "RES 1981/ 51" was written instead of "RES 1981/051" 

parsed_docs_df[parsed_docs_df.filename == "277.pdf"]
# Out:
#     filename                                                              url  \
# 253  277.pdf  https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/277.pdf
#
#      year    pub_number
# 253  1981  RES 1981/051

# %%
# TODO: fix these mistakes
parsed_docs_df[parsed_docs_df['pub_number'].str.contains(r'\s.*\s', na=False)]
# Out:
# Empty DataFrame
# Columns: [filename, url, year, pub_number]
# Index: []

# %% [markdown]
# # check single non-matching pdf for translations inside of the single pdf

# %%
# how many files are just a single link?

print(combined_df[combined_df.url_fr == combined_df.url_en].shape[0])

combined_df[combined_df.url_fr == combined_df.url_en].sample(10)
# Out:
# 561
#       type  year  pub_number  \
# 334    PRO  2003    2003/039
# 288    PRO  2002    2002/012
# 19715  SSR  1999  1999/A6-13
# 502    PRO  2006    2006/039
# 181    PRO  2000    2000/015
# 351    PRO  2003    2003/040
# 486    PRO  2006    2006/026
# 85     PRO  1998    1998/004
# 379    PRO  2004    2004/020
# 19656  SSR  1999  1999/A2-19
#
#                                                                                                                                                                                                            nom  \
# 334                                                    Compte rendu du Processus consultatif régional des Maritimes concernant le crabe des neiges de l'est du plateau néo-écossais; du 26 au 27 février 2003.
# 288                                                                                                                                                                                                        NaN
# 19715                                                                                                                                                                                                      NaN
# 502    Compte rendu de la réunion du Processus consultatif régional concernant l'évaluation du potentiel de rétablissement du requin taupe bleu, du requin blanc et de la carette de l'Atlantique; 28-30 no...
# 181                                                                                                                                                                                                        NaN
# 351                                                                                                          Procès-verbal de la réunion du Sous-comité sur le poisson de fond du CEESP; 8 et 9 décembre 2003.
# 486    Ateliers d'évaluation des dommages acceptables pour les espèces en péril d'eau douce dans la Région du Centre et de l'Arctique; les 18 et 19 octobre 2005, les 8 et 9 février 2006 et les 13 et 14 f...
# 85                                                                                                                                                                                                         NaN
# 379                Compte rendu d'une réunion du Processus consultatif régional au sujet des dommages acceptables au saumon atlantique de l'arrière-baie de Fundy en tant qu'espèce en péril; le 6 avril 2004.
# 19656                                                                                                                                                                                                      NaN
#
#                                                                                                                                                                         name  \
# 334                                                      Proceedings of the Maritimes Regional Advisory Process of the Eastern Scotian Shelf Snow Crab; 26-27 February 2003.
# 288                                                                                     Proceedings of the National Marine Mammal Review Committee, Quebec, Feb. 18-20, 2002
# 19715                                                                                                                              Redstripe Rockfish British Columbia Coast
# 502                   Proceedings of the Maritime Provinces Recovery Potential Assessment of Atlantic Shortfin Mako, White Shark, and Loggerhead Turtle; 28-30 November 2006
# 181                                                                                                       Report of the PSARC Habitat Subcommittee Meeting; August 22, 2000.
# 351                                                                                            Proceedings of the PSARC Groundfish Subcommittee Meeting; December 8-9, 2003.
# 486        Allowable Harm Analysis Workshops for Freshwater Species at Risk in Central and Arctic Region; October 18-19, 2005; February 8-9, 2006; and February 13-14, 2006.
# 85                                    Report of the PSARC Invertebrate Subcommittee Meeting January 26, and 28-30, 1998 and the Steering Committee Meeting February 18, 1998
# 379    Proceedings of a Regional Advisory Process Meeting on the Level of Allowable Harm for Inner Bay of Fundy Atlantic Salmon in Support of Species at Risk; 6 April 2004.
# 19656                                                                                                                                Newfoundland Region Groundfish Overview
#
#                                                      url_fr  \
# 334    http://waves-vagues.dfo-mpo.gc.ca/Library/277996.pdf
# 288    http://waves-vagues.dfo-mpo.gc.ca/Library/264851.pdf
# 19715  http://waves-vagues.dfo-mpo.gc.ca/Library/331718.pdf
# 502    http://waves-vagues.dfo-mpo.gc.ca/Library/326922.pdf
# 181    http://waves-vagues.dfo-mpo.gc.ca/Library/331484.pdf
# 351    http://waves-vagues.dfo-mpo.gc.ca/Library/345261.pdf
# 486    http://waves-vagues.dfo-mpo.gc.ca/Library/325726.pdf
# 85     http://waves-vagues.dfo-mpo.gc.ca/Library/359491.pdf
# 379    http://waves-vagues.dfo-mpo.gc.ca/Library/283267.pdf
# 19656  http://waves-vagues.dfo-mpo.gc.ca/Library/317695.pdf
#
#                                                      url_en  \
# 334    http://waves-vagues.dfo-mpo.gc.ca/Library/277996.pdf
# 288    http://waves-vagues.dfo-mpo.gc.ca/Library/264851.pdf
# 19715  http://waves-vagues.dfo-mpo.gc.ca/Library/331718.pdf
# 502    http://waves-vagues.dfo-mpo.gc.ca/Library/326922.pdf
# 181    http://waves-vagues.dfo-mpo.gc.ca/Library/331484.pdf
# 351    http://waves-vagues.dfo-mpo.gc.ca/Library/345261.pdf
# 486    http://waves-vagues.dfo-mpo.gc.ca/Library/325726.pdf
# 85     http://waves-vagues.dfo-mpo.gc.ca/Library/359491.pdf
# 379    http://waves-vagues.dfo-mpo.gc.ca/Library/283267.pdf
# 19656  http://waves-vagues.dfo-mpo.gc.ca/Library/317695.pdf
#
#       formatted_pub_number
# 334           PRO 2003/039
# 288           PRO 2002/012
# 19715       SSR 1999/A6-13
# 502           PRO 2006/039
# 181           PRO 2000/015
# 351           PRO 2003/040
# 486           PRO 2006/026
# 85            PRO 1998/004
# 379           PRO 2004/020
# 19656       SSR 1999/A2-19

# %% [markdown]
# # break into paragraph chunks

# %%
# TODO: break into paragraph chunks for better correlation 
#  TODO (OPTIONAL): clean excess characters
#  TODO (OPTIONAL): make sure french-friendly encoding is used (at least check if that makes a difference)
