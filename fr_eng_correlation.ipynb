# %%
import json
import os
import random
import re
import tempfile
import pandas as pd

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>")) # jupyter notebook full-width display
display(HTML("<style>.dataframe td { white-space: nowrap; }</style>")) # no text wrapping

# pandas formatting
pd.set_option('display.float_format', '{:.1f}'.format)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 200)
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.dataframe td { white-space: nowrap; }</style>

# %% [markdown]
# # import url data

# %%
links_folder = "website_reports"

dataframes = []

for file in os.listdir(links_folder):
    if file.endswith(".xlsx"):
        file_path = os.path.join(links_folder, file)
        df = pd.read_excel(file_path)
        dataframes.append(df)

column_names = ['type', 'year', 'pub_number', '_', 'nom', 'name', 'url_fr', 'url_en', '_', '_', '_', '_']
combined_df = pd.concat(dataframes, ignore_index=True)
combined_df.columns = column_names
display(combined_df.head())

types = ['RES', 'SAR', 'PRO', 'SSR', 'SCR', 'ESR', 'HSR']
combined_df = combined_df[combined_df.type.isin(types)]
combined_df = combined_df.loc[:, combined_df.columns != '_']
# Out:
#      type  year          pub_number        _  \
# 0  SERIES  YEAR  PUBLICATION NUMBER  AUTHORS
# 1     ESR  2003            2003/002  DFO-MPO
# 2     ESR  2003            2003/005  DFO-MPO
# 3     ESR  2003            2003/004  DFO-MPO
# 4     ESR  2003            2003/003  DFO-MPO
#
#                                                                                                                                              nom  \
# 0                                                                                                                                   TITLE FRENCH
# 1  État de l'océan en 2001 : Conditions océanographiques physiques sur le plateau néo-écossais, dans la baie de Fundy et dans le golfe du Maine.
# 2   État de l'océan en 2002 : Conditions océanographiques physiques sur le plateau néo-écossais, dans la baie de Fundy et dans legolfe du Maine.
# 3                                                                                         État de l'écosystème de l'est du plateau néo-écossais.
# 4                                  État de l'océan en 2002 : Conditions océanographiques physiques dans la Région de Terre-Neuve et du Labrador.
#
#                                                                                                                name  \
# 0                                                                                                     TITLE ENGLISH
# 1  2001 State of the Ocean: Physical Oceanographic Conditions on the Scotian Shelf, Bay of Fundy and Gulf of Maine.
# 2  2002 State of the Ocean: Physical Oceanographic Conditions on the Scotian Shelf, Bay of Fundy and Gulf of Maine.
# 3                                                                     State of the Eastern Scotian Shelf Ecosystem.
# 4               2002 State of the Ocean: Physical oceanographic conditions in the Newfoundland and Labrador Region.
#
#                                                  url_fr  \
# 0                                            URL FRENCH
# 1  http://waves-vagues.dfo-mpo.gc.ca/Library/279108.pdf
# 2  http://waves-vagues.dfo-mpo.gc.ca/Library/280817.pdf
# 3  http://waves-vagues.dfo-mpo.gc.ca/Library/277606.pdf
# 4  http://waves-vagues.dfo-mpo.gc.ca/Library/336493.pdf
#
#                                                  url_en              _  \
# 0                                           URL ENGLISH  URL INUKTITUT
# 1  http://waves-vagues.dfo-mpo.gc.ca/Library/276322.pdf            NaN
# 2  http://waves-vagues.dfo-mpo.gc.ca/Library/281583.pdf            NaN
# 3  http://waves-vagues.dfo-mpo.gc.ca/Library/276323.pdf            NaN
# 4  http://waves-vagues.dfo-mpo.gc.ca/Library/336490.pdf            NaN
#
#                          _                        _                    _
# 0           REGION ENGLISH            REGION FRENCH       DATE PUBLISHED
# 1                Maritimes                Maritimes  2003-05-02 00:00:00
# 2                Maritimes                Maritimes                  NaN
# 3                Maritimes                Maritimes                  NaN
# 4  Newfoundland & Labrador  Terre-Neuve et Labrador  2004-01-12 00:00:00

# %%
combined_df.sample(10)
# Out:
#       type  year pub_number  \
# 7476   RES  2001   2001/045
# 5793   RES  1997   1997/141
# 9191   RES  2005   2005/032
# 17396  SAR  2009   2009/008
# 12082  RES  2012   2012/092
# 1769   RES  1980   1980/054
# 6470   RES  1999   1999/069
# 6399   RES  1999   1999/043
# 12401  RES  2012   2012/151
# 2598   RES  1985   1985/078
#
#                                                                                                                                                             nom  \
# 7476                                                     Évaluation des stocks de hareng de la zone 4T de l'OPANO dans le sud du golfe du Saint-Laurent en 2000
# 5793                                                                                                                                                        NaN
# 9191   Évaluation de la sensibilité de l'habitat marin : une étude de cas sur la zostère marine (Zostera marina L.) et des laminaires (Laminaria, Macrocystis).
# 17396                                                                                                      Évaluation du stock de morue de la sous-division 3Ps
# 12082                                                     Distribution de l'effort de pêche à la crevette nordique dans l'estuaire et le golfe du Saint-Laurent
# 1769                                                                                                                                                        NaN
# 6470                                                                                                                                                        NaN
# 6399                                                                                                                                                        NaN
# 12401                                                        Prises accessoires de la pêche à la crevette nordique dans l'estuaire et le golfe du Saint-Laurent
# 2598                                                                                                                                                        NaN
#
#                                                                                                                            name  \
# 7476                                                  Assessment of the 4T southern Gulf of St. Lawrence herring stocks in 2000
# 5793                     A retrospective analysis of escapement model performance using different adult survival rate estimate.
# 9191   Assessing marine habitat sensitivity: a case study with eelgrass (Zostera marina L.) and kelps (Laminaria, Macrocystis).
# 17396                                                                                   Stock Assessment of Subdivision 3Ps Cod
# 12082                                    Distribution of Northern shrimp fishing effort in the Estuary and Gulf of St. Lawrence
# 1769                                                               An evaluation of the current status of southern Gulf herring
# 6470                                                                    Assessment of the Banquereau Bank Artic Surfclam, 1999.
# 6399                    Changes in the timing and location of cod spawning in Placentia Bay (NAFO sub-division 3Ps), 1997-1998.
# 12401                                                   Bycatch in the Estuary and Gulf of St. Lawrence Northern shrimp fishery
# 2598                                                                                 Assessment of the 1984 4WX herring fishery
#
#                                                                                        url_fr  \
# 7476    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/2001/2001_045-fra.htm
# 5793    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1997/1997_141-fra.htm
# 9191    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/2005/2005_032-fra.htm
# 17396            http://www.dfo-mpo.gc.ca/csas-sccs/Publications/SAR-AS/2009/2009_008-fra.htm
# 12082  http://www.dfo-mpo.gc.ca/csas-sccs/Publications/ResDocs-DocRech/2012/2012_092-fra.html
# 1769   http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1980/1980_054-fra.html
# 6470    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1999/1999_069-fra.htm
# 6399    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1999/1999_043-fra.htm
# 12401  http://www.dfo-mpo.gc.ca/csas-sccs/Publications/ResDocs-DocRech/2012/2012_151-fra.html
# 2598   http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1985/1985_078-fra.html
#
#                                                                                        url_en
# 7476    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/2001/2001_045-eng.htm
# 5793    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1997/1997_141-eng.htm
# 9191    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/2005/2005_032-eng.htm
# 17396            http://www.dfo-mpo.gc.ca/csas-sccs/Publications/SAR-AS/2009/2009_008-eng.htm
# 12082  http://www.dfo-mpo.gc.ca/csas-sccs/Publications/ResDocs-DocRech/2012/2012_092-eng.html
# 1769   http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1980/1980_054-eng.html
# 6470    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1999/1999_069-eng.htm
# 6399    http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1999/1999_043-eng.htm
# 12401  http://www.dfo-mpo.gc.ca/csas-sccs/Publications/ResDocs-DocRech/2012/2012_151-eng.html
# 2598   http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1985/1985_078-eng.html

# %% [markdown]
# ### remove untranslated documents

# %%
# # first take a look at value counts
# display(combined_df.loc[combined_df.url_fr == combined_df.url_en, 'year'].value_counts())
# display(combined_df.loc[combined_df.url_fr != combined_df.url_en, 'year'].value_counts())
# display(combined_df.loc[combined_df.url_fr == combined_df.url_en, 'type'].value_counts())
# display(combined_df.loc[combined_df.url_fr != combined_df.url_en, 'type'].value_counts())

combined_df = combined_df[combined_df.url_fr != combined_df.url_en]

combined_df[combined_df['url_en'].str.endswith(('html', 'htm'))]['type'].value_counts()
# Out:
# type
# RES    5063
# SAR    1126
# PRO     840
# SCR     655
# ESR       1
# Name: count, dtype: int64

# %% [markdown]
# ### create formatted pub number with type and number

# %%
combined_df['formatted_pub_number'] = combined_df['type'] + " " + combined_df['pub_number']

# %%
combined_df.sample(1).T
# Out:
#                                                                                                                                                                                             5936
# type                                                                                                                                                                                         RES
# year                                                                                                                                                                                        1998
# pub_number                                                                                                                                                                              1998/046
# nom                                                                                                                                                                                          NaN
# name                  Analyses of trends in returns of Atlantic salmon (Salmo salar) to rivers in Nova Scotia and Bay of Fundy, New Brunswick, and status of 1997 returns relative to forecasts.
# url_fr                                                                                                     http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1998/1998_046-fra.htm
# url_en                                                                                                     http://www.dfo-mpo.gc.ca/csas-sccs/publications/resdocs-docrech/1998/1998_046-eng.htm
# formatted_pub_number                                                                                                                                                                RES 1998/046

# %% [markdown]
# # import ParsedPublication data

# %%
parsed_docs_folder = os.path.join("..", "ParsedPublications")

type_dict = {
    'RES': ['research document', 'documents de recherche', 'document de recherche', 'res doc', 'res no', 'resdoc', 'res'],
    'SCR': ['science response report', 'science response', 'reponses des sciences', 'reponses des science', 'reponse scientifique'],
    'PRO': ['proceedings series', 'comptes rendus', 'compte rendus', 'comptes rendu', 'compte rendu'],
    'SAR': ['science advisory report', 'avis scientifique'],
}
data = []
errors = dict()

def extract_pub_number(text, filename):
    text_snippet = re.sub(r"\s+", " ", text[:2000].replace(".", "").replace('é', 'e').lower())
    
    # TODO = REMOVE: old versions for testing = this is the old borderless bug version, but has more results
    # for key, phrases in type_dict.items():  
    #     pattern = re.compile("|".join(re.escape(phrase.lower()) for phrase in phrases), flags=re.IGNORECASE)
    #     text_snippet = pattern.sub(key, text_snippet)
    for key, phrases in type_dict.items():
        pattern = re.compile(r"\b(" + "|".join(re.escape(phrase.lower()) for phrase in phrases) + r")\b", flags=re.IGNORECASE)
        text_snippet = pattern.sub(key, text_snippet)
    
    # TODO = REMOVE: old versions for testing = this is the old borderless bug version, but has more results
    # patterns = [rf"{key}(?:\s+no\.)?\s+\d{{2,4}}/\d{{1,3}}" for key in type_dict.keys()]  
    patterns = [rf"{key}(?:\s+no\.)?\s+\d{{2,4}}\s*/\s*\d{{1,3}}" for key in type_dict.keys()]
    # patterns = [rf"{key}\.?(?:\s+no\.)?\s+\d{{2,4}}\s*/\s*\d{{1,3}}" for key in type_dict.keys()]
    # patterns = [rf"{key}(?:\s+doc)?(?:\s+no)?\s+\d{{2,4}}\s*/\s*\d{{1,3}}" for key in type_dict.keys()]
    # patterns = [rf"{key}\.?(\s+doc\.?)?(?:\s+no\.?)?\s+\d{{2,4}}\s*/\s*\d{{1,3}}" for key in type_dict.keys()]
    
    for pattern in patterns:
        match = re.search(pattern, text_snippet, re.IGNORECASE)
        if match:
            pub_number = match.group()
            
            # Normalize 2-digit years to 4 digits (e.g., 77 -> 1977)
            pub_number = re.sub(r" (\d{2})/", lambda m: f" 19{m.group(1)}/" if int(m.group(1)) <= 99 else f" {m.group(1)}/", pub_number)
            
            # Zero-pad publication numbers (e.g., 15 -> 015)
            pub_number = re.sub(r"/(\d{1,2})(?!\d)", lambda m: f"/{int(m.group(1)):03}", pub_number)
            return pub_number
    
    errors[filename] = " ".join(text_snippet.split())
    return None

for year_folder in os.listdir(parsed_docs_folder):
    min_year = 1977
    max_year = 2024
    
    if year_folder.isnumeric():
        if min_year <= int(year_folder) <= max_year:
            year_path = os.path.join(parsed_docs_folder, year_folder)
            print(f"Analysing: {year_path}")
            
            if os.path.isdir(year_path):
                for json_file in os.listdir(year_path):
                    if json_file.endswith(".json"):
                        json_path = os.path.join(year_path, json_file)
                        with open(json_path, 'r', encoding='utf-8') as file:
                            json_data = json.load(file)
                            
                            filename = json_data.get('name')
                            url = json_data.get('url')
                            year = json_data.get('publicationYear')
                            text = json_data.get('text', '')
                            pub_number = extract_pub_number(text, filename)
                            
                            data.append({
                                'filename': filename,
                                'url': url,
                                'year': year,
                                'pub_number': pub_number
                            })

parsed_docs_df = pd.DataFrame(data)
# Out:
# Analysing: ..\ParsedPublications\1977
# Analysing: ..\ParsedPublications\1978
# Analysing: ..\ParsedPublications\1979
# Analysing: ..\ParsedPublications\1980
# Analysing: ..\ParsedPublications\1981
# Analysing: ..\ParsedPublications\1982
# Analysing: ..\ParsedPublications\1983
# Analysing: ..\ParsedPublications\1984
# Analysing: ..\ParsedPublications\1985
# Analysing: ..\ParsedPublications\1986
# Analysing: ..\ParsedPublications\1987
# Analysing: ..\ParsedPublications\1988
# Analysing: ..\ParsedPublications\1989
# Analysing: ..\ParsedPublications\1990
# Analysing: ..\ParsedPublications\1991
# Analysing: ..\ParsedPublications\1992
# Analysing: ..\ParsedPublications\1993
# Analysing: ..\ParsedPublications\1994
# Analysing: ..\ParsedPublications\1995
# Analysing: ..\ParsedPublications\1996
# Analysing: ..\ParsedPublications\1997
# Analysing: ..\ParsedPublications\1998
# Analysing: ..\ParsedPublications\1999
# Analysing: ..\ParsedPublications\2000
# Analysing: ..\ParsedPublications\2001
# Analysing: ..\ParsedPublications\2002
# Analysing: ..\ParsedPublications\2003
# Analysing: ..\ParsedPublications\2004
# Analysing: ..\ParsedPublications\2005
# Analysing: ..\ParsedPublications\2006
# Analysing: ..\ParsedPublications\2007
# Analysing: ..\ParsedPublications\2008
# Analysing: ..\ParsedPublications\2009
# Analysing: ..\ParsedPublications\2010
# Analysing: ..\ParsedPublications\2011
# Analysing: ..\ParsedPublications\2012
# Analysing: ..\ParsedPublications\2013
# Analysing: ..\ParsedPublications\2014
# Analysing: ..\ParsedPublications\2015
# Analysing: ..\ParsedPublications\2016
# Analysing: ..\ParsedPublications\2017
# Analysing: ..\ParsedPublications\2018
# Analysing: ..\ParsedPublications\2019
# Analysing: ..\ParsedPublications\2020
# Analysing: ..\ParsedPublications\2021
# Analysing: ..\ParsedPublications\2022
# Analysing: ..\ParsedPublications\2023
# Analysing: ..\ParsedPublications\2024

# %%
# missing "Compte rendus 2020/004" - need borders (files: 40874424.pdf, 40876032.pdf)
# # 3521 for 400char at 150s
# # 1991 for 2000char at 13s / 12s / 3min (wut)
# # 1963 for 3000char at 14s / 14s
# # 1944 for 5000char at 120s    
# # 1820 for 10000char at 31s / 108s / 212s (what is happening?)
# len(errors)

# UPDATED WITH BOUNDARIES
# 1900 for 2000char at 3m7s 
len(errors)
# Out:
# 2459

# %%
# # the only one after 1982 - new keyword added
# errors['4072296x.pdf']

# %%
# older version before the version above was "FIXED"

parsed_docs_folder = os.path.join("..", "ParsedPublications")

type_dict = {
    'RES': ['research document', 'res. doc.', 'res doc', 'res.doc.', 'res no.', 'resdoc', 'res.', 'res', 'documents de recherche', 'document de recherche'],
    'SCR': ['science response', 'science response report', 'réponse des sciences', 'réponses des sciences', 'réponse scientifique'],
    'PRO': ['proceedings series', 'compte rendu', 'compte rendus', 'comptes rendu', 'comptes rendus'],
    'SAR': ['science advisory report', 'avis scientifique'],
}
data = []
errors = dict()

def extract_pub_number(text, filename):
    text_snippet = re.sub(r"\s+", " ", text[:2000].lower())
    

    for key, phrases in type_dict.items():
        pattern = re.compile(r"\b(" + "|".join(re.escape(phrase.lower()) for phrase in phrases) + r")\b", flags=re.IGNORECASE)
        text_snippet = pattern.sub(key, text_snippet)
    

    patterns = [rf"{key}\.?(?:\s+no\.)?\s+\d{{2,4}}\s*/\s*\d{{1,3}}" for key in type_dict.keys()]

    
    for pattern in patterns:
        match = re.search(pattern, text_snippet, re.IGNORECASE)
        if match:
            pub_number = match.group()
            
            # Normalize 2-digit years to 4 digits (e.g., 77 -> 1977)
            pub_number = re.sub(r" (\d{2})/", lambda m: f" 19{m.group(1)}/" if int(m.group(1)) <= 99 else f" {m.group(1)}/", pub_number)
            
            # Zero-pad publication numbers (e.g., 15 -> 015)
            pub_number = re.sub(r"/(\d{1,2})(?!\d)", lambda m: f"/{int(m.group(1)):03}", pub_number)
            return pub_number
    
    errors[filename] = " ".join(text_snippet.split())
    return None

for year_folder in os.listdir(parsed_docs_folder):
    min_year = 1977
    max_year = 2024
    
    if year_folder.isnumeric():
        if min_year <= int(year_folder) <= max_year:
            year_path = os.path.join(parsed_docs_folder, year_folder)
            print(f"Analysing: {year_path}")
            
            if os.path.isdir(year_path):
                for json_file in os.listdir(year_path):
                    if json_file.endswith(".json"):
                        json_path = os.path.join(year_path, json_file)
                        with open(json_path, 'r', encoding='utf-8') as file:
                            json_data = json.load(file)
                            
                            filename = json_data.get('name')
                            url = json_data.get('url')
                            year = json_data.get('publicationYear')
                            text = json_data.get('text', '')
                            pub_number = extract_pub_number(text, filename)
                            
                            data.append({
                                'filename': filename,
                                'url': url,
                                'year': year,
                                'pub_number': pub_number
                            })

parsed_docs_df = pd.DataFrame(data)

len(errors)
# Out:
# Analysing: ..\ParsedPublications\1977
# Analysing: ..\ParsedPublications\1978
# Analysing: ..\ParsedPublications\1979
# Analysing: ..\ParsedPublications\1980
# Analysing: ..\ParsedPublications\1981
# Analysing: ..\ParsedPublications\1982
# Analysing: ..\ParsedPublications\1983
# Analysing: ..\ParsedPublications\1984
# Analysing: ..\ParsedPublications\1985
# Analysing: ..\ParsedPublications\1986
# Analysing: ..\ParsedPublications\1987
# Analysing: ..\ParsedPublications\1988
# Analysing: ..\ParsedPublications\1989
# Analysing: ..\ParsedPublications\1990
# Analysing: ..\ParsedPublications\1991
# Analysing: ..\ParsedPublications\1992
# Analysing: ..\ParsedPublications\1993
# Analysing: ..\ParsedPublications\1994
# Analysing: ..\ParsedPublications\1995
# Analysing: ..\ParsedPublications\1996
# Analysing: ..\ParsedPublications\1997
# Analysing: ..\ParsedPublications\1998
# Analysing: ..\ParsedPublications\1999
# Analysing: ..\ParsedPublications\2000
# Analysing: ..\ParsedPublications\2001
# Analysing: ..\ParsedPublications\2002
# Analysing: ..\ParsedPublications\2003
# Analysing: ..\ParsedPublications\2004
# Analysing: ..\ParsedPublications\2005
# Analysing: ..\ParsedPublications\2006
# Analysing: ..\ParsedPublications\2007
# Analysing: ..\ParsedPublications\2008
# Analysing: ..\ParsedPublications\2009
# Analysing: ..\ParsedPublications\2010
# Analysing: ..\ParsedPublications\2011
# Analysing: ..\ParsedPublications\2012
# Analysing: ..\ParsedPublications\2013
# Analysing: ..\ParsedPublications\2014
# Analysing: ..\ParsedPublications\2015
# Analysing: ..\ParsedPublications\2016
# Analysing: ..\ParsedPublications\2017
# Analysing: ..\ParsedPublications\2018
# Analysing: ..\ParsedPublications\2019
# Analysing: ..\ParsedPublications\2020
# Analysing: ..\ParsedPublications\2021
# Analysing: ..\ParsedPublications\2022
# Analysing: ..\ParsedPublications\2023
# Analysing: ..\ParsedPublications\2024
# 1900

# %%
# wish.com regex

parsed_docs_folder = os.path.join("..", "ParsedPublications")

type_dict = {
    'RES': ['research document', 'res. doc.', 'res doc', 'res.doc.', 'res no.', 'resdoc', 'res.', 'res', 'documents de recherche', 'document de recherche'],
    'SCR': ['science response', 'science response report', 'réponse des sciences', 'réponses des sciences', 'réponse scientifique'],
    'PRO': ['proceedings series', 'compte rendu', 'compte rendus', 'comptes rendu', 'comptes rendus'],
    'SAR': ['science advisory report', 'avis scientifique'],
}
data = []
errors = dict()

def extract_pub_number(text, filename):
    text_snippet = re.sub(r"\s+", " ", text[:200].replace("\xa0", " ").lower())
    
    for key, phrases in type_dict.items():
        for phrase in phrases:
            pattern = re.compile(rf"\b{re.escape(phrase.lower())}\b", flags=re.IGNORECASE)
            print(pattern)
            text_snippet = pattern.sub(key, text_snippet)
            print(text_snippet)
    
    patterns = [rf"{key}\.?(\s+doc)?(\s+no)?\s+\d{{2,4}}\s*/\s*\d{{1,3}}" for key in type_dict.keys()]
    
    
    for pattern in patterns:
        match = re.search(pattern, text_snippet, re.IGNORECASE)
        if match:
            pub_number = match.group()
            
            # Normalize 2-digit years to 4 digits (e.g., 77 -> 1977)
            pub_number = re.sub(r" (\d{2})/", lambda m: f" 19{m.group(1)}/" if int(m.group(1)) <= 99 else f" {m.group(1)}/", pub_number)
            
            # Zero-pad publication numbers (e.g., 15 -> 015)
            pub_number = re.sub(r"/(\d{1,2})(?!\d)", lambda m: f"/{int(m.group(1)):03}", pub_number)
            return pub_number
    
    errors[filename] = " ".join(text_snippet.split())
    return None

for year_folder in os.listdir(parsed_docs_folder):
    min_year = 1977
    max_year = 1977
    
    if year_folder.isnumeric():
        if min_year <= int(year_folder) <= max_year:
            year_path = os.path.join(parsed_docs_folder, year_folder)
            print(f"Analysing: {year_path}")
            
            if os.path.isdir(year_path):
                for json_file in os.listdir(year_path):
                    
                    if json_file.endswith(".json"):
                        json_path = os.path.join(year_path, json_file)
                        with open(json_path, 'r', encoding='utf-8') as file:
                            json_data = json.load(file)
                            
                            filename = json_data.get('name')
                            url = json_data.get('url')
                            year = json_data.get('publicationYear')
                            text = json_data.get('text', '')
                            pub_number = extract_pub_number(text, filename)
                            
                            data.append({
                                'filename': filename,
                                'url': url,
                                'year': year,
                                'pub_number': pub_number
                            })
                            break

parsed_docs_df = pd.DataFrame(data)

len(errors)
# Out:
# Analysing: ..\ParsedPublications\1977
# re.compile('\\bresearch\\ document\\b', re.IGNORECASE)
#  fr'• r res. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bres\\.\\ doc\\.\\b', re.IGNORECASE)
#  fr'• r res. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bres\\ doc\\b', re.IGNORECASE)
#  fr'• r res. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bres\\.doc\\.\\b', re.IGNORECASE)
#  fr'• r res. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bres\\ no\\.\\b', re.IGNORECASE)
#  fr'• r res. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bresdoc\\b', re.IGNORECASE)
#  fr'• r res. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bres\\.\\b', re.IGNORECASE)
#  fr'• r res. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bres\\b', re.IGNORECASE)
#  fr'• r RES. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bdocuments\\ de\\ recherche\\b', re.IGNORECASE)
#  fr'• r RES. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bdocument\\ de\\ recherche\\b', re.IGNORECASE)
#  fr'• r RES. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bscience\\ response\\b', re.IGNORECASE)
#  fr'• r RES. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bscience\\ response\\ report\\b', re.IGNORECASE)
#  fr'• r RES. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bréponse\\ des\\ sciences\\b', re.IGNORECASE)
#  fr'• r RES. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bréponses\\ des\\ sciences\\b', re.IGNORECASE)
#  fr'• r RES. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bréponse\\ scientifique\\b', re.IGNORECASE)
#  fr'• r RES. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bproceedings\\ series\\b', re.IGNORECASE)
#  fr'• r RES. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bcompte\\ rendu\\b', re.IGNORECASE)
#  fr'• r RES. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bcompte\\ rendus\\b', re.IGNORECASE)
#  fr'• r RES. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bcomptes\\ rendu\\b', re.IGNORECASE)
#  fr'• r RES. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bcomptes\\ rendus\\b', re.IGNORECASE)
#  fr'• r RES. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bscience\\ advisory\\ report\\b', re.IGNORECASE)
#  fr'• r RES. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# re.compile('\\bavis\\ scientifique\\b', re.IGNORECASE)
#  fr'• r RES. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology labo
# 1

# %%
# get rid of border because wrecks periods, sorted lists should be good enough
# TODO: clean up. I think this thing actually works, clean up then update replacements list 

parsed_docs_folder = os.path.join("..", "ParsedPublications")

type_dict = {
    'RES': ['research document', 'res. doc.', 'res doc', 'res.doc.', 'res no.', 'resdoc', 'res.', 'res', 'documents de recherche', 'document de recherche'],
    'SCR': ['science response', 'science response report', 'réponse des sciences', 'réponses des sciences', 'réponse scientifique'],
    'PRO': ['proceedings series', 'compte rendu', 'compte rendus', 'comptes rendu', 'comptes rendus'],
    'SAR': ['science advisory report', 'avis scientifique'],
}
data = []
errors = dict()

def extract_pub_number(text, filename):
    text_snippet = re.sub(r"\s+", " ", text[:2000].lower())
    

    for key, phrases in type_dict.items():
        pattern = re.compile(r"(" + "|".join(re.escape(phrase.lower()) for phrase in phrases) + r")", flags=re.IGNORECASE)
        text_snippet = pattern.sub(key, text_snippet)
    

    patterns = [rf"{key}\.?(?:\s+no\.)?\s+\d{{2,4}}\s*/\s*\d{{1,3}}" for key in type_dict.keys()]

    
    for pattern in patterns:
        match = re.search(pattern, text_snippet, re.IGNORECASE)
        if match:
            pub_number = match.group()
            
            # Normalize 2-digit years to 4 digits (e.g., 77 -> 1977)
            pub_number = re.sub(r" (\d{2})/", lambda m: f" 19{m.group(1)}/" if int(m.group(1)) <= 99 else f" {m.group(1)}/", pub_number)
            
            # Zero-pad publication numbers (e.g., 15 -> 015)
            pub_number = re.sub(r"/(\d{1,2})(?!\d)", lambda m: f"/{int(m.group(1)):03}", pub_number)
            return pub_number
    
    errors[filename] = " ".join(text_snippet.split())
    return None

for year_folder in os.listdir(parsed_docs_folder):
    min_year = 1977
    max_year = 2024
    
    if year_folder.isnumeric():
        if min_year <= int(year_folder) <= max_year:
            year_path = os.path.join(parsed_docs_folder, year_folder)
            print(f"Analysing: {year_path}")
            
            if os.path.isdir(year_path):
                for json_file in os.listdir(year_path):
                    if json_file.endswith(".json"):
                        json_path = os.path.join(year_path, json_file)
                        with open(json_path, 'r', encoding='utf-8') as file:
                            json_data = json.load(file)
                            
                            filename = json_data.get('name')
                            url = json_data.get('url')
                            year = json_data.get('publicationYear')
                            text = json_data.get('text', '')
                            pub_number = extract_pub_number(text, filename)
                            
                            data.append({
                                'filename': filename,
                                'url': url,
                                'year': year,
                                'pub_number': pub_number
                            })

parsed_docs_df = pd.DataFrame(data)

len(errors)
# Out:
# Analysing: ..\ParsedPublications\1977
# Analysing: ..\ParsedPublications\1978
# Analysing: ..\ParsedPublications\1979
# Analysing: ..\ParsedPublications\1980
# Analysing: ..\ParsedPublications\1981
# Analysing: ..\ParsedPublications\1982
# Analysing: ..\ParsedPublications\1983
# Analysing: ..\ParsedPublications\1984
# Analysing: ..\ParsedPublications\1985
# Analysing: ..\ParsedPublications\1986
# Analysing: ..\ParsedPublications\1987
# Analysing: ..\ParsedPublications\1988
# Analysing: ..\ParsedPublications\1989
# Analysing: ..\ParsedPublications\1990
# Analysing: ..\ParsedPublications\1991
# Analysing: ..\ParsedPublications\1992
# Analysing: ..\ParsedPublications\1993
# Analysing: ..\ParsedPublications\1994
# Analysing: ..\ParsedPublications\1995
# Analysing: ..\ParsedPublications\1996
# Analysing: ..\ParsedPublications\1997
# Analysing: ..\ParsedPublications\1998
# Analysing: ..\ParsedPublications\1999
# Analysing: ..\ParsedPublications\2000
# Analysing: ..\ParsedPublications\2001
# Analysing: ..\ParsedPublications\2002
# Analysing: ..\ParsedPublications\2003
# Analysing: ..\ParsedPublications\2004
# Analysing: ..\ParsedPublications\2005
# Analysing: ..\ParsedPublications\2006
# Analysing: ..\ParsedPublications\2007
# Analysing: ..\ParsedPublications\2008
# Analysing: ..\ParsedPublications\2009
# Analysing: ..\ParsedPublications\2010
# Analysing: ..\ParsedPublications\2011
# Analysing: ..\ParsedPublications\2012
# Analysing: ..\ParsedPublications\2013
# Analysing: ..\ParsedPublications\2014
# Analysing: ..\ParsedPublications\2015
# Analysing: ..\ParsedPublications\2016
# Analysing: ..\ParsedPublications\2017
# Analysing: ..\ParsedPublications\2018
# Analysing: ..\ParsedPublications\2019
# Analysing: ..\ParsedPublications\2020
# Analysing: ..\ParsedPublications\2021
# Analysing: ..\ParsedPublications\2022
# Analysing: ..\ParsedPublications\2023
# Analysing: ..\ParsedPublications\2024
# 1806

# %%
test_phrase = "fr'• r res. doc. 77/1 this report not to be cited without prior reference..."

# does not work
print(re.compile(rf"\b{re.escape("res.".lower())}\b", flags=re.IGNORECASE).sub('RES', test_phrase))

# works
print(re.compile(rf"\b{re.escape("res".lower())}\b", flags=re.IGNORECASE).sub('RES', test_phrase))
# Out:
# fr'• r res. doc. 77/1 this report not to be cited without prior reference...
# fr'• r RES. doc. 77/1 this report not to be cited without prior reference...

# %%
test_phrase = "fr'• r res. doc. 77/1 this report not to be cited without prior reference..."

print(re.compile(rf"{re.escape("res.".lower())}", flags=re.IGNORECASE).sub('RES', test_phrase))
print(re.compile(rf"{re.escape("res".lower())}", flags=re.IGNORECASE).sub('RES', test_phrase))
# Out:
# fr'• r RES doc. 77/1 this report not to be cited without prior reference...
# fr'• r RES. doc. 77/1 this report not to be cited without prior reference...

# %%
random_error = random.choice(list(errors.keys()))

print(random_error)
print(errors[random_error])
# Out:
# 212967.pdf
# fisheries pêches and oceans et océans mpo science région des maritimes rapport sur l’état des stocks a3-02 juin 1997 morue de sydney bight renseignements de base la sous-division 4vn est une zone ou viennent se mélanger les morues résidantes et les grands stocks des zones avoisinantes, le stock de 4t à l’ouest et le stock de 4vsw au sud. de plus, la morue de 4t passe l’hiver le long de la limite supérieure du talus continental, de sydney bight jusque dans la région du banquereau, quittant le golfe à la fin de l’automne pour y revenir au printemps. pendant cette période, les captures de morue dans la sous-division 4vn incluent des morues résidantes et des morues du golfe, bien que la morue de 4t compose la plus grande partie des prises, puisqu’il s’agit d’un stock beaucoup plus important. ainsi, des quantités inconnues de morue de 4vn sont capturées pendant la période d’hivernage. le mélange des morues du golfe du saint-laurent (4t) avec le stock résidant et l’incapacité de répartir les débarquements en fonction des stocks ont compliqué l’évaluation et la gestion du stock de 4vn. la morue de 4vn croît plus lentement que celle de 4vsw au sud, mais tout de même plus rapidement que celle de 4t. il semble qu’elle atteigne la maturité à l’âge 5. les études de marquage indiquent qu’elle passe l’hiver dans des eaux plus profondes. elle fraye en mai, dans sydney bight. 4s 4t 4vn 3ps 4vs4w 3pn la pêche débarquements (milliers de tonnes) 70-79 80-89 1992 1993 1994 1995 1996 tac 6,7 10,5 10,0 1,8 * * * débarquements** 5,1 8,6 2,3 0,7 <0,1 <0,1 <0,1 débarquements*** 7,1 10,6 4,5 0,7 <0,1 <0,1 <0,1 * captures accidentelles seulement ** de mai à octobre seulement *** de mai à décembre seulement débarquements et tac (t) 0 2000 4000 6000 8000 10000 12000 14000 1970 1975 1980 1985 1990 1995 2000 tac débarquements avant que le canada étende sa compétence en matière de pêche en 1977, la pêche de la morue dans la sous-division 4vn avait touj

# %%
# errors_10k = errors.copy()
# errors_3k = errors.copy()
# errors_2k = errors.copy()
# errors_2k_v2 = errors.copy()
# error_diff_10k = [k for k in errors_2k if k not in errors_10k]
# errors_2k_v3 = errors.copy()

# %%
errors_2k_v2['75586.pdf']
# Out:
# 'fr\'• r RES. doc. 77/1 this report not to be cited without prior reference to the author . tue grouping of herring populations in the southern gulf of st. lawrence by d.m. ware fine ecology laboratory, bedford institute of oceanography, dartmouth, n.s. introduction in the course of analysing the growth of herring larvae in st. georges bay, nova scotia, i was puzzled by the fact that the observed growth rates, which agreed favourably with other estimates, seemed to be inconsistent with the back-calculated lengths-at-age 1. this report summarizes the problem, as i see it, that might exist with our current age determination and grouping of herring\'pbpulations in the southern gulf of st. lawrence. although the interpretation i suggest reconciles the larval growth rates with the back-calculated lengths-at-age 1, several points are quite speculative and require verification, or revision, on the basis of new evidence. however (from a management point of view), the implications of the existing data are important enough that i am willing to stick my neck out somewhat prematurely and tender the following observations. herring spawning groups according to the temporal variation in the proportion of mature fish in the catch in different areas (day, 1957a; tibbo, 1957), the herring in the southern gulf of st. lawrence can be separated into four spawning groups (table 1). instead of callingall the fish caught in may and june "spring" herring, as we have traditionally done, there seems to be sufficient evidence to distinguish a spring (group a) and early summer (group b) spawning population*. similarly, the -2- herring caught in the "autumn" can be divided into a late summer (group c) and autumn (group d) spawning group. since the existing information is quite sketchy for several of the spring and early summer fisheries, i have assumed that the first spawning of the year occurs in the northern half of the magdalen shallows. the water tempera'

# %%
error_diff = [k for k in errors_2k_v3 if k not in errors_2k]
# these are from references, 10k is too long, 
#  even 3k is too long for some of them, some are correct...
#   96/87F, 96/92F - what is the F? 
parsed_docs_df[parsed_docs_df.filename.isin(error_diff)]
# Out:
#        filename  \
# 0     75586.pdf
# 2     75588.pdf
# 3     75589.pdf
# 4     75590.pdf
# 5     75591.pdf
# 6     75593.pdf
# 7     75594.pdf
# 8     75595.pdf
# 14    75601.pdf
# 15    75603.pdf
# 16    75604.pdf
# 17    75605.pdf
# 18    75606.pdf
# 19    75607.pdf
# 20    75608.pdf
# 22    75610.pdf
# 23    75611.pdf
# 24    75612.pdf
# 27    75623.pdf
# 28    75624.pdf
# 29    75625.pdf
# 31   325769.pdf
# 33    75627.pdf
# 35    75629.pdf
# 37    75631.pdf
# 38    75632.pdf
# 39    75633.pdf
# 41    75635.pdf
# 42    75636.pdf
# 43    75637.pdf
# 44    75638.pdf
# 45    75639.pdf
# 46    75640.pdf
# 47    75641.pdf
# 48    75642.pdf
# 49    75643.pdf
# 51    75646.pdf
# 52    75647.pdf
# 53    75648.pdf
# 54    75649.pdf
# 55    75650.pdf
# 56    75651.pdf
# 57    75652.pdf
# 58    75653.pdf
# 60    75655.pdf
# 61    75658.pdf
# 62    75659.pdf
# 63    75661.pdf
# 64    75662.pdf
# 65    75663.pdf
# 66    75664.pdf
# 67    75665.pdf
# 68    75666.pdf
# 69    75667.pdf
# 70    75668.pdf
# 71    75669.pdf
# 73    75671.pdf
# 82    75676.pdf
# 89    75683.pdf
# 95    75689.pdf
# 109   75703.pdf
# 121   75715.pdf
# 123   75717.pdf
# 126   13499.pdf
# 127   13500.pdf
# 130  325849.pdf
# 132   66092.pdf
# 140   79443.pdf
# 150   79453.pdf
# 155   79458.pdf
# 175   79478.pdf
# 186   79489.pdf
# 199   79516.pdf
# 211     118.pdf
# 212     122.pdf
# 213     123.pdf
# 217     140.pdf
# 222     165.pdf
# 236     217.pdf
# 241     228.pdf
# 249     261.pdf
# 252     264.pdf
# 257     281.pdf
# 258     282.pdf
# 266     372.pdf
# 268     375.pdf
# 280     693.pdf
# 281     694.pdf
# 293   19126.pdf
# 301   29147.pdf
# 305   31645.pdf
# 306   32614.pdf
# 318   36669.pdf
#
#                                                                     url  year  \
# 0     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75586.pdf  1977
# 2     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75588.pdf  1977
# 3     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75589.pdf  1977
# 4     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75590.pdf  1977
# 5     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75591.pdf  1977
# 6     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75593.pdf  1977
# 7     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75594.pdf  1977
# 8     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75595.pdf  1977
# 14    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75601.pdf  1977
# 15    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75603.pdf  1977
# 16    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75604.pdf  1977
# 17    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75605.pdf  1977
# 18    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75606.pdf  1977
# 19    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75607.pdf  1977
# 20    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75608.pdf  1977
# 22    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75610.pdf  1977
# 23    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75611.pdf  1977
# 24    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75612.pdf  1977
# 27    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75623.pdf  1977
# 28    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75624.pdf  1977
# 29    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75625.pdf  1977
# 31   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/325769.pdf  1978
# 33    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75627.pdf  1978
# 35    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75629.pdf  1978
# 37    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75631.pdf  1978
# 38    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75632.pdf  1978
# 39    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75633.pdf  1978
# 41    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75635.pdf  1978
# 42    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75636.pdf  1978
# 43    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75637.pdf  1978
# 44    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75638.pdf  1978
# 45    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75639.pdf  1978
# 46    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75640.pdf  1978
# 47    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75641.pdf  1978
# 48    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75642.pdf  1978
# 49    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75643.pdf  1978
# 51    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75646.pdf  1978
# 52    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75647.pdf  1978
# 53    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75648.pdf  1978
# 54    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75649.pdf  1978
# 55    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75650.pdf  1978
# 56    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75651.pdf  1978
# 57    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75652.pdf  1978
# 58    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75653.pdf  1978
# 60    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75655.pdf  1978
# 61    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75658.pdf  1978
# 62    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75659.pdf  1978
# 63    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75661.pdf  1978
# 64    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75662.pdf  1978
# 65    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75663.pdf  1978
# 66    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75664.pdf  1978
# 67    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75665.pdf  1978
# 68    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75666.pdf  1978
# 69    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75667.pdf  1978
# 70    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75668.pdf  1978
# 71    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75669.pdf  1978
# 73    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75671.pdf  1978
# 82    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75676.pdf  1979
# 89    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75683.pdf  1979
# 95    https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75689.pdf  1979
# 109   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75703.pdf  1979
# 121   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75715.pdf  1979
# 123   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75717.pdf  1979
# 126   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/13499.pdf  1980
# 127   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/13500.pdf  1980
# 130  https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/325849.pdf  1980
# 132   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/66092.pdf  1980
# 140   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/79443.pdf  1980
# 150   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/79453.pdf  1980
# 155   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/79458.pdf  1980
# 175   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/79478.pdf  1980
# 186   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/79489.pdf  1980
# 199   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/79516.pdf  1980
# 211     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/118.pdf  1981
# 212     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/122.pdf  1981
# 213     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/123.pdf  1981
# 217     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/140.pdf  1981
# 222     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/165.pdf  1981
# 236     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/217.pdf  1981
# 241     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/228.pdf  1981
# 249     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/261.pdf  1981
# 252     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/264.pdf  1981
# 257     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/281.pdf  1981
# 258     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/282.pdf  1981
# 266     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/372.pdf  1981
# 268     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/375.pdf  1981
# 280     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/693.pdf  1981
# 281     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/694.pdf  1981
# 293   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/19126.pdf  1982
# 301   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/29147.pdf  1982
# 305   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/31645.pdf  1982
# 306   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/32614.pdf  1982
# 318   https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/36669.pdf  1982
#
#     pub_number
# 0         None
# 2         None
# 3         None
# 4         None
# 5         None
# 6         None
# 7         None
# 8         None
# 14        None
# 15        None
# 16        None
# 17        None
# 18        None
# 19        None
# 20        None
# 22        None
# 23        None
# 24        None
# 27        None
# 28        None
# 29        None
# 31        None
# 33        None
# 35        None
# 37        None
# 38        None
# 39        None
# 41        None
# 42        None
# 43        None
# 44        None
# 45        None
# 46        None
# 47        None
# 48        None
# 49        None
# 51        None
# 52        None
# 53        None
# 54        None
# 55        None
# 56        None
# 57        None
# 58        None
# 60        None
# 61        None
# 62        None
# 63        None
# 64        None
# 65        None
# 66        None
# 67        None
# 68        None
# 69        None
# 70        None
# 71        None
# 73        None
# 82        None
# 89        None
# 95        None
# 109       None
# 121       None
# 123       None
# 126       None
# 127       None
# 130       None
# 132       None
# 140       None
# 150       None
# 155       None
# 175       None
# 186       None
# 199       None
# 211       None
# 212       None
# 213       None
# 217       None
# 222       None
# 236       None
# 241       None
# 249       None
# 252       None
# 257       None
# 258       None
# 266       None
# 268       None
# 280       None
# 281       None
# 293       None
# 301       None
# 305       None
# 306       None
# 318       None

# %%
parsed_docs_df.head()
# Out:
#     filename  \
# 0  75586.pdf
# 1  75587.pdf
# 2  75588.pdf
# 3  75589.pdf
# 4  75590.pdf
#
#                                                                  url  year  \
# 0  https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75586.pdf  1977
# 1  https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75587.pdf  1977
# 2  https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75588.pdf  1977
# 3  https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75589.pdf  1977
# 4  https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/75590.pdf  1977
#
#      pub_number
# 0  RES 1977/001
# 1          None
# 2  RES 1977/003
# 3  RES 1977/004
# 4  RES 1977/006

# %%
error_diff = {k: v for k, v in errors_2k.items() if k not in errors_10k}

# %%
def display_errors_in_notepad(errors):
    with tempfile.NamedTemporaryFile(delete=False, mode='w', suffix='.txt', encoding='utf-8') as temp_file:
        for k, v in errors.items():
            v = v.lower()
            
            if "stock status report" not in v:
                temp_file.write(f'++++++++++++++++++++ {k} ++++++++++++++++++++\n')
                temp_file.write(f'{v}\n\n')
        temp_file_name = temp_file.name
    
    os.system(f'notepad {temp_file_name}')
    os.unlink(temp_file_name)


display_errors_in_notepad(error_diff)

# %%
parsed_docs_df['pub_number'].isna().value_counts()
# Out:
# pub_number
# False    6742
# True     6010
# Name: count, dtype: int64

# %%
parsed_docs_df.sample(10)
# Out:
#            filename  \
# 4069     276692.pdf
# 1426     167904.pdf
# 1809     197630.pdf
# 8660     364202.pdf
# 4797     315755.pdf
# 12396  41220031.pdf
# 5606     335277.pdf
# 8945     364478.pdf
# 4385     282442.pdf
# 12626  41243924.pdf
#
#                                                                         url  \
# 4069     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/276692.pdf
# 1426     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/167904.pdf
# 1809     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/197630.pdf
# 8660     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/364202.pdf
# 4797                   http://waves-vagues.dfo-mpo.gc.ca/Library/315755.pdf
# 12396  https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/41220031.pdf
# 5606     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/335277.pdf
# 8945     https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/364478.pdf
# 4385                   http://waves-vagues.dfo-mpo.gc.ca/Library/282442.pdf
# 12626  https://waves-vagues.dfo-mpo.gc.ca/library-bibliotheque/41243924.pdf
#
#        year                        pub_number
# 4069   2002                              None
# 1426   1994                              None
# 1809   1996                              None
# 8660   2014  Science Advisory Report 2014/040
# 4797   2005                              None
# 12396  2023     Réponse des Sciences 2023/044
# 5606   2007       Proceedings Series 2008/001
# 8945   2015  Science Advisory Report 2015/003
# 4385   2003                              None
# 12626  2024        Avis scientifique 2024/027

# %% [markdown]
# # create pub_number for combined_df

# %% [markdown]
# # check all json for matches by year, type, pub_number

# %% [markdown]
# # Plan B: get json filename from url using BS4

# %%
# how many are html links vs pdf links?
display(combined_df['url_en'].str.endswith(('html', 'htm')).value_counts())
display(combined_df['url_en'].str.endswith('pdf').value_counts())
# Out:
# url_en
# True     7685
# False     815
# Name: count, dtype: int64
# url_en
# False    7685
# True      815
# Name: count, dtype: int64

# %%
# TODO: check ParsedPublications (these seem to have the pdf url, hopefully names match) <== NOPE. just the direct link to the pdf. 
#  TODO: try creating a pub number and using that
#   TODO: use beautiful soup to look for href="*.pdf"?

# %% [markdown]
# # break into paragraph chunks

# %%
# TODO: break into paragraph chunks for better correlation 
#  TODO (OPTIONAL): clean excess characters
#  TODO (OPTIONAL): make sure french-friendly encoding is used (at least check if that makes a difference)
